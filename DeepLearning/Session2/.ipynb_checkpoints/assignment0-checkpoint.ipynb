# %% [markdown]
# # The easiest assignment in this course

# %% [markdown]
# Cope one of these notebooks (`Linear SoftMax Classifier.ipynb`, `Polynomial SoftMax Classifier.ipynb`) and replace the model with multilayer neural network. Play with nonlinearities, also generate your own, more entangled data and check your models perfrmance. Good luck!

# %%
from matplotlib import pyplot as plt
import numpy as np
import time
from IPython.display import clear_output
from sklearn.datasets import make_moons, make_circles
from sklearn.preprocessing import OneHotEncoder
import itertools

import tensorflow as tf
# Out:
# Bad key "xtick.alignment" on line 250 in
# /usr/share/matplotlib/mpl-data/stylelib/classic.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key "ytick.alignment" on line 268 in
# /usr/share/matplotlib/mpl-data/stylelib/classic.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution

# %%
from sklearn.datasets.samples_generator import make_circles,make_moons

N = 100 # number of points per class
D = 2 # dimensionality
p = 4 # polynomial degree
K = 2 # number of classes
X = []
y = []

X, y = make_circles(noise=0.1,random_state=0,n_samples=200,factor=0.2)
plt.scatter(X[:, 0], X[:, 1],c=y)
# enc = OneHotEncoder()
# enc.fit(y.reshape([y.shape[0],1]))
# y = enc.transform(y.reshape([y.shape[0],1])).toarray()

# %%
def featurize(x, p=1):
    return np.product(np.power(x, list(x for x in itertools.product(range(p+1), repeat=2) if sum(x) <=p)), axis=-1)

# %%
def plot(h=0.02):
    x_min, x_max = X[:, 0].min() - 0.5, X[:, 0].max() + 0.5
    y_min, y_max = X[:, 1].min() - 0.5, X[:, 1].max() + 0.5
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                 np.arange(y_min, y_max, h))
    
    
    Z = sess.run(t_prediction, feed_dict={t_x: 
        [featurize(x, p) for x in np.column_stack([xx.ravel(), yy.ravel()])]})
    Z = Z.reshape(xx.shape)

    plt.figure(figsize=(10,8))
    plt.contourf(xx, yy, Z, cmap=plt.cm.Spectral, alpha=0.8)
    plt.scatter(X[:, 0], X[:, 1], c=y, s=40, cmap=plt.cm.Spectral, edgecolors="black")
    plt.xlim(xx.min(), xx.max())
    plt.ylim(yy.min(), yy.max())
    plt.gca().set_aspect("equal")
    plt.show()

# %%
X_big = np.stack([featurize(x, p) for x in X])

# %%
reg = 1e-3 # regularization strength

# Encapsulating all ops into scopes, making Tensorboard's Graph
# Visualization more convenient
with tf.name_scope("Model"):
    t_x = tf.placeholder(tf.float32, shape=[None, X_big.shape[1]])
    t_y = tf.placeholder(tf.int32, shape=[None])
    W_h = tf.Variable(tf.random_normal([X_big.shape[1], 32]),name='first')
    first = tf.matmul(t_x,W_h)
    act = tf.nn.relu(first)
    W = tf.Variable(tf.random_normal([32, K]),name='second')
    t_scores = tf.matmul(act, W)
    t_prediction = tf.argmax(t_scores, axis=-1, output_type=tf.int32)

with tf.name_scope("Loss"):
    t_loss_entropy = tf.nn.sparse_softmax_cross_entropy_with_logits(labels=t_y, logits=t_scores)
    t_loss_reg = tf.reduce_sum(W * W) * reg
    t_loss = tf.reduce_mean(t_loss_entropy + t_loss_reg)

with tf.name_scope("Optimizer"):
    optimizer = tf.train.AdamOptimizer()
    
    t_grads = tf.gradients(t_loss, tf.trainable_variables())
    grads_and_vars = list(zip(t_grads, tf.trainable_variables()))
    train_op = optimizer.apply_gradients(grads_and_vars)
    

with tf.name_scope("Accuracy"):
    t_acc = tf.reduce_mean(tf.cast(tf.equal(t_prediction, t_y), tf.float32))

# %%
# Create a summary to monitor cost tensor
tf.summary.scalar("loss", t_loss)
# Create a summary to monitor accuracy tensor
tf.summary.scalar("accuracy", t_acc)
# Create summaries to visualize weights
for var in tf.trainable_variables():
    tf.summary.histogram(var.name, var)
# Summarize all gradients
for grad, var in grads_and_vars:
    tf.summary.histogram(var.name + '/gradient', grad)
    
# Merge all summaries into a single op
merged_summary_op = tf.summary.merge_all()
# Out:
# INFO:tensorflow:Summary name Model/first:0 is illegal; using Model/first_0 instead.
# INFO:tensorflow:Summary name Model/second:0 is illegal; using Model/second_0 instead.
# INFO:tensorflow:Summary name Model/first:0/gradient is illegal; using Model/first_0/gradient instead.
# INFO:tensorflow:Summary name Model/second:0/gradient is illegal; using Model/second_0/gradient instead.

# %%
# op to write logs to Tensorboard
summary_writer = tf.summary.FileWriter(logdir="/tmp/tf_logs/",
                                        graph=tf.get_default_graph())

# %%
if "sess" in dir():
    sess.close()
sess = tf.Session()
sess.run(tf.global_variables_initializer())
iteration = 0

# %%
for i in range(10000):
    loss, acc, _, summary = sess.run([t_loss, t_acc, train_op, merged_summary_op], 
                                     feed_dict={t_x:X_big, t_y:y})
    iteration += 1
    summary_writer.add_summary(summary, iteration)

    time.sleep(0.0000001)
    
    if i % 2000 == 0:
        clear_output(wait=True)
        plot(h=0.05)
        print("iteration %d:\tloss %f\tacc %f" % (i, loss, acc))
# Out:
# iteration 8000:	loss 0.000236	acc 1.000000

# %%
# evaluate training set accuracy
print('training accuracy: %.2f%%' % (100*sess.run(t_acc, feed_dict={t_x:X_big, t_y:y})))
# Out:
# training accuracy: 100.00%
